# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(
    { "figure.figsize": (17, 7) },
    style='ticks',
    palette=sns.color_palette("Set2"),
    color_codes=True,
    font_scale=0.8
)
# %config InlineBackend.figure_format = 'retina'
import warnings
warnings.filterwarnings('ignore')

# %%
dfs_df = pd.read_csv("results/dfs_results_small_sample.csv")
bfs_df = pd.read_csv("results/bfs_results_small_sample.csv")

# %%
sns.pointplot(dfs_df, x="grid_size", y="average_time_ns")
sns.pointplot(bfs_df, x="grid_size", y="average_time_ns")
# Out:
# <Axes: xlabel='grid_size', ylabel='average_time_ns'>
